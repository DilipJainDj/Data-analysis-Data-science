# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column
#df["Start Date"]=pd.to_datetime(df["Start Date"])
#df["Last Login Time"]=pd.to_datetime(df["Last Login Time"])
df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")

# %%
df.info()
48.9/62.6 #we reduced the approx 22% of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB
# 0.7811501597444089

# %% [markdown]
# #  Filter A DataFrame Based on a Condition

# %%
df[df["Gender"] =="Male"].head(3)
#assigning over code for getting only True Values
#for comparision always remeber to use comparision opretor
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-10-25 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
#df[df["Team"] =="Finance"].head(3)
#or
mask=df["Team"] =="Finance"
df[mask].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-10-25 13:00:00  138705    9.340
# 7        NaN  Female 2015-07-20 2018-10-25 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 3               True  Finance
# 7               True  Finance

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
#df[df["Team"] =="Finance"].head(3)
#or
mask=df["Team"] =="Finance"
df[mask].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-10-25 13:00:00  138705    9.340
# 7        NaN  Female 2015-07-20 2018-10-25 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 3               True  Finance
# 7               True  Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
mask=df["Team"] !="Marketing"
df[mask].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-10-25 13:00:00  138705    9.340
#
#    Senior Management     Team
# 1               True      NaN
# 2              False  Finance
# 3               True  Finance

# %%
df[df["Salary"]> 11000].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask=df["Start Date"] <="1985-01-01"
df[mask].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10     Louise  Female 1980-08-12 2018-10-25 09:01:00   63241   15.132
# 12    Brandon    Male 1980-12-01 2018-10-25 01:08:00  112807   17.492
# 18      Diana  Female 1981-10-23 2018-10-25 10:27:00  132940   19.082
#
#     Senior Management             Team
# 10               True              NaN
# 12               True  Human Resources
# 18              False  Client Services

# %% [markdown]
# # Filter with More than One Condition(AND)

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-25 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Gender"]=="Male"
mask2 = df["Team"]=="Marketing"
df[mask1 & mask2].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2018-10-25 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2018-10-25 07:45:00   37598    7.757
# 74     Thomas   Male 1995-06-04 2018-10-25 14:24:00   62096   17.029
# 77    Charles   Male 2004-09-14 2018-10-25 20:13:00  107391    1.260
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing
# 74              False  Marketing
# 77               True  Marketing

# %% [markdown]
# # comparing using OR(|) operator

# %%
mask1 = df["Senior Management"]
mask2 =df["Start Date"] < "1990-01-01"
df[mask1 | mask2].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2018-10-25 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2018-10-25 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2018-10-25 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2018-10-25 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2018-10-25 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
df["First Name"]=="Robert"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c20bcd7779e0> in <module>()
# ----> 1 df["First Name"]=="Robert"
#
# NameError: name 'df' is not defined

# %%
mask1=df["First Name"] == "Robert"
mask2 =df["Team"]=="Client Services"
mask3 =df["Start Date"] >"2016-06-01"
df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2018-10-25 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2018-10-25 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2018-10-25 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2018-10-25 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# # The .isin() Method

# %%
import pandas as pd
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-26 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-26 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Team"]=="Legal"
mask2 = df["Team"] =="Sales"
mask3 =df["Team"] == "Product"
df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2018-10-26 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-10-26 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2018-10-26 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2018-10-26 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2018-10-26 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
mask=df["Team"].isin(["Legal" , "Sales" , "Product"])
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2018-10-26 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-10-26 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2018-10-26 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2018-10-26 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2018-10-26 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-26 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-26 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask =df["Team"].isnull()

# %%
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2018-10-26 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2018-10-26 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2018-10-26 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2018-10-26 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
mask = df["Team"].isnull()#gives false here
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2018-10-26 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2018-10-26 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2018-10-26 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2018-10-26 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
mask = df["Gender"].notnull()# gives true values here and also remove the nan values


df[mask].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-26 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-26 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-10-26 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-10-26 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# # .between() Method

# %%
df[df["Salary"].between(60000,70000)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-10-26 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2018-10-26 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2018-10-26 09:01:00   63241   15.132
# 20       Lois     NaN 1995-04-22 2018-10-26 19:18:00   64714    4.934
# 41  Christine     NaN 2015-06-28 2018-10-26 01:08:00   66582   11.308
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# 20               True                 Legal
# 41               True  Business Development

# %%
import pandas as pd
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-10-29 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-10-29 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-10-29 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
df[df["Bonus %"].between(2.0 , 5.0)].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas   Male 1996-03-31 2018-10-29 06:53:00   61933    4.170
# 20       Lois    NaN 1995-04-22 2018-10-29 19:18:00   64714    4.934
# 40    Michael   Male 2008-10-10 2018-10-29 11:25:00   99283    2.665
# 49      Chris    NaN 1980-01-24 2018-10-29 12:13:00  113590    3.055
# 60      Paula    NaN 2005-11-23 2018-10-29 14:01:00   48866    4.271
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution
# 49              False         Sales
# 60              False  Distribution

# %%
df[df["Start Date"].between("1991-01-01","1992-01-01")].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2018-10-29 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2018-10-29 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2018-10-29 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2018-10-29 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2018-10-29 02:24:00  124488   14.837
#
#      Senior Management             Team
# 27               False            Legal
# 75                True  Human Resources
# 88                True            Legal
# 116               True            Legal
# 148               True            Sales

# %%
df[df["Last Login Time"].between("08:30AM","12:00PM")].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-10-29 11:17:00  130590   11.858
# 7         NaN  Female 2015-07-20 2018-10-29 10:43:00   45906   11.598
# 10     Louise  Female 1980-08-12 2018-10-29 09:01:00   63241   15.132
# 18      Diana  Female 1981-10-23 2018-10-29 10:27:00  132940   19.082
# 33       Jean  Female 1993-12-18 2018-10-29 09:07:00  119082   16.180
#
#     Senior Management                  Team
# 2               False               Finance
# 7                True               Finance
# 10               True                   NaN
# 18              False       Client Services
# 33              False  Business Development

# %% [markdown]
# # The .duplicate() Method

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date" , "Last Login Time"]) # the parse_dates method is used to remove the below two steps and it take the list argumgent in form of string or name of column

df["Senior Management"]=df["Senior Management"].astype("bool")
df["Gender"]=df["Gender"].astype("category")
df.sort_values("First Name",inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-10-29 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-10-29 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-10-29 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df["First Name"].duplicated().head()#default parameter is(subset=None, keep='first')
#all the first value that is  come first  is False and all other are True
#You can also change the Default parameter that is passing by default
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
# Name: First Name, dtype: bool

# %%
mask = ~df["First Name"].duplicated(keep = False)
df[mask].head()
# all the member that is duplicat is showing by this command
#by using the tiled symbol we change the functionalty of this command  and now it is showing only the unique vales
# ~=tiled symbol that is used for negation
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-10-29 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-10-29 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-10-29 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-10-29 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-10-29 01:35:00  115163   10.125
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance
# 887              False        Legal
# 5                False        Legal

# %% [markdown]
# # The .drop_duplicates() Method

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates()) #If we want to remove the duplicates in our values than
#We have to change these parameter that is bydefault (subset=None, keep='first', inplace=False)
#subset contain the list arguments
# Out:
# 1000

# %%
df.drop_duplicates(subset  = ["First Name"] , keep  =False).head() # only unique values is showing
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-10-29 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-10-29 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-10-29 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-10-29 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-10-29 01:35:00  115163   10.125
#
#      Senior Management         Team
# 8                 True  Engineering
# 688               True        Legal
# 190              False      Finance
# 887              False        Legal
# 5                False        Legal

# %%
df.drop_duplicates(subset=["Team"],keep  = False) 
# all the teams is coming more than one so nothing is showing in the list
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df.drop_duplicates(subset=["First Name" , "Team"] , inplace = True)
#The above code is used to differentiate  both name  and team

# %%
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-10-29 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2018-10-29 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2018-10-29 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution

# %%
len(df) # before len is1000
# Out:
# 769

# %% [markdown]
# # The .unique() and .nunique() Methods

# %%
df["Gender"].unique()
# Out:
# [Male, NaN, Female]
# Categories (2, object): [Male, Female]

# %%
df["Team"].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df["Team"].unique()) # counting the nan value
# Out:
# 11

# %%
df["Team"].nunique() 
#not counting the nan values  and also the paramenter is passed by default(axis=0, dropna=True)
# Out:
# 10
