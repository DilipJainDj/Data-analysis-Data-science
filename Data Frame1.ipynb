# %%
import pandas as pd

# %%
a = pd.read_csv("nba.csv")#nba = National basketball Asociation

# %%
a.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ## Shared Methods and Attributes

# %%
a.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
a.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
a.shape
# Out:
# (458, 9)

# %%
a.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
a.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
a.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
a.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
a.get_dtype_counts() # Returns the how much data type is available
# Out:
# float64    4
# object     5
# dtype: int64

# %% [markdown]
# #### Differences between Shared Methods

# %%
r =pd.read_csv("revenue.csv",index_col="Date")

# %%
r.head()
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
s = pd.Series([1,2,3])

# %%
s.sum()
# Out:
# 6

# %%
r.sum() # this type of sum can only be counted by in series
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
r.sum(axis ="index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
r.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
#  Difference Between Series and DataFrame in sum method
#  In Series datastructure we can only be able to sum in only one way but in the Data Frame we can sum both coloumn as well as Row

# %% [markdown]
# ## Select One Column from a DataFrame

# %%
a.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
a.Name
a.Number
a.Salary.head(4)
# Out:
# 0    7730337.0
# 1    6796117.0
# 2          NaN
# 3    1148640.0
# Name: Salary, dtype: float64

# %%
# To hide the output
a.Salary
Output  = None

# %%
a["Name"].head() # same as above
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
type(a["Name"]) # it's a Series object
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Select two or More Columns From A Data Frame

# %%
a.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
a[["Name","Team"]].head(4)
# Out:
#             Name            Team
# 0  Avery Bradley  Boston Celtics
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics

# %%
a[["Team","Name"]].head(3)
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland

# %%
select = ["Salary","Team","Name"]

# %%
a[select].head(4)
# Out:
#       Salary            Team           Name
# 0  7730337.0  Boston Celtics  Avery Bradley
# 1  6796117.0  Boston Celtics    Jae Crowder
# 2        NaN  Boston Celtics   John Holland
# 3  1148640.0  Boston Celtics    R.J. Hunter

# %% [markdown]
# ### Add New Column to DataFrame

# %%
a["Sport"] = "Basketball" # This creats a new column and assin the value :"Basketball"

# %%
a.head(3) # You can see the New column at the end of Row
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
a["Leauge"] = "National Basketball Association"

# %%
a.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                           Leauge
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association

# %%
a.insert(3 , column="Match", value="5")
#it insert the new column at particular Location

# %%
a.head(3)
# Out:
#             Name            Team  Number Match        khel Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0     5  Basketball       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0     5  Basketball       SF  25.0
# 2   John Holland  Boston Celtics    30.0     5  Basketball       SG  27.0
#
#   Height  Weight            College     Salary       Sport  \
# 0    6-2   180.0              Texas  7730337.0  Basketball
# 1    6-6   235.0          Marquette  6796117.0  Basketball
# 2    6-5   205.0  Boston University        NaN  Basketball
#
#                             Leauge
# 0  National Basketball Association
# 1  National Basketball Association
# 2  National Basketball Association

# %% [markdown]
# ##  Broadcasting

# %%
import pandas as pd
nba  =pd.read_csv("nba.csv")
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
nba["Age"].add(5).head(3)
# Out:
# 0    30.0
# 1    30.0
# 2    32.0
# Name: Age, dtype: float64

# %%
(nba["Age"]+5) .head(3)
# Out:
# 0    30.0
# 1    30.0
# 2    32.0
# Name: Age, dtype: float64

# %%
nba["Salary"].head(3)
# Out:
# 0    7730337.0
# 1    6796117.0
# 2          NaN
# Name: Salary, dtype: float64

# %%
nba["Salary"].sub(500000).head(4)
# Out:
# 0    7230337.0
# 1    6296117.0
# 2          NaN
# 3     648640.0
# Name: Salary, dtype: float64

# %%
(nba["Salary"]-50000 ).head(3)
# Out:
# 0    7680337.0
# 1    6746117.0
# 2          NaN
# Name: Salary, dtype: float64

# %%
nba["Weight"].mul(0.45392).head(3)
# Out:
# 0     81.7056
# 1    106.6712
# 2     93.0536
# Name: Weight, dtype: float64

# %%
nba["Weight in Kilogram"] = nba["Weight"]*0.45392

# %%
nba.head(3) # Weight in Kilogram is at the last of table
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Kilogram
# 0              Texas  7730337.0             81.7056
# 1          Marquette  6796117.0            106.6712
# 2  Boston University        NaN             93.0536

# %%
nba["Salary"].div(1000000).head(3)
# Out:
# 0    7.730337
# 1    6.796117
# 2         NaN
# Name: Salary, dtype: float64

# %%
nba["Salary in Million"]=(nba["Salary"]/1000000)

# %%
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary  Weight in Kilogram  Salary in Million
# 0              Texas  7730337.0             81.7056           7.730337
# 1          Marquette  6796117.0            106.6712           6.796117
# 2  Boston University        NaN             93.0536                NaN
# 3      Georgia State  1148640.0             83.9752           1.148640

# %% [markdown]
# ### A Review of the .Value_Counts() Method

# %%
nba  =pd.read_csv("nba.csv")
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
nba["Team"].value_counts().head(3)
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# New York Knicks         16
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts().tail(4)
# Out:
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba["Salary"].value_counts().head()#common salary in nba
# Out:
# 947276.0     31
# 845059.0     18
# 525093.0     13
# 981348.0      6
# 1100602.0     5
# Name: Salary, dtype: int64

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna().tail()# Remove all the rows that contain the NaN Value 
# Example like remove the 457 raw
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 449    Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0      Duke
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 449  1348440.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 456   947276.0

# %%
nba.dropna(how ="all").head() # it checks all the column of each row if all is Nan than the row is deleted automatically
# In this row 2nd is arrise again
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.dropna(how="all" , inplace=True)

# %%
nba.tail()# remove the last raw that contain the NAN values
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis = 1).head()# remove the column that contain the none value But Not permanantaly unti we use the inplace parameter
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0

# %%
nba.dropna(axis = "columns" , inplace=True)

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0

# %%
nba  =pd.read_csv("nba.csv")
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
nba.dropna(subset=["Salary"]) .head()# Remove all the raw that contain the NAN value in Salary columns
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#          College      Salary
# 0          Texas   7730337.0
# 1      Marquette   6796117.0
# 3  Georgia State   1148640.0
# 4            NaN   5000000.0
# 5            NaN  12000000.0

# %%
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
nba.fillna(0).head(4)# fill all NAN value with 0(zero)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0

# %%
nba["Salary"].fillna(0 , inplace = True)

# %%
nba.to_csv('abc1.csv')# for saving the file with all changes that you perform on the File

# %%
nba.head(4)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0

# %%
nba["College"].fillna("No College" , inplace = True)

# %%
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ## The.astype() Method

# %%
nba  = pd.read_csv("nba.csv").dropna(how='all')

# %%
nba["Salary"].fillna(0 , inplace = True)
nba["College"].fillna("None" , inplace = True)
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4               None  5000000.0

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info() # give all details and total memories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"]=nba["Salary"].astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Number"]=nba["Number"].astype("int")

# %%
nba["Age"] = nba["Age"].astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Age"].astype("float").head(3)
# Out:
# 0    25.0
# 1    25.0
# 2    27.0
# Name: Age, dtype: float64

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int32
# Position    457 non-null category
# Age         457 non-null int32
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int32
# dtypes: category(1), float64(1), int32(3), object(4)
# memory usage: 27.4+ KB

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null category
# Number      457 non-null int32
# Position    457 non-null category
# Age         457 non-null int32
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null int32
# dtypes: category(2), float64(1), int32(3), object(3)
# memory usage: 25.8+ KB

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values('Name').head(3)
# Out:
#                Name               Team  Number Position   Age Height  Weight  \
# 152    Aaron Brooks      Chicago Bulls     0.0       PG  31.0    6-0   161.0
# 356    Aaron Gordon      Orlando Magic     0.0       PF  20.0    6-9   220.0
# 328  Aaron Harrison  Charlotte Hornets     9.0       SG  21.0    6-6   210.0
#
#       College     Salary
# 152    Oregon  2250000.0
# 356   Arizona  4171680.0
# 328  Kentucky   525093.0

# %%
nba.sort_values("Age",ascending=False).head(3)
# Out:
#               Name                    Team  Number Position   Age Height  \
# 304   Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400  Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298     Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
#
#      Weight      College     Salary
# 304   200.0         Utah   250750.0
# 400   240.0          NaN  8500000.0
# 298   250.0  Wake Forest  5250000.0

# %%
nba.sort_values("Salary" ,ascending=False, inplace=True)

# %%
nba.head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College      Salary
# 109   212.0       NaN  25000000.0
# 169   250.0       NaN  22970500.0
# 33    240.0  Syracuse  22875000.0

# %%
nba.sort_values("Salary",na_position="first").head(13)# By this we can  make the list of Salary columns that contain the NaN values
# Out:
#                        Name                    Team  Number Position   Age  \
# 2              John Holland          Boston Celtics    30.0       SG  27.0
# 46              Elton Brand      Philadelphia 76ers    42.0       PF  37.0
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG  24.0
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG  24.0
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# ...

# %%
nba.sort_values("Salary" , ascending=False , na_position="first").tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %% [markdown]
# ## Sort a DataFrame with  the .sort_values() Method , part 2nd

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Team","Name"] , ascending=[True , False] , inplace = True)

# %%
nba.head(3)
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks    22.0        C  24.0    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
#
#       College     Salary
# 322       NaN  1000000.0
# 310  Michigan  1304520.0
# 321       NaN  9756250.0

# %% [markdown]
# ### Sort DataFrame with the .sort_index() Method

# %%
nba = pd.read_csv("nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
 nba.sort_values(["Number","Salary" , "Name"],inplace  =True)
nba.tail()
# Out:
#                Name                Team  Number Position   Age Height  Weight  \
# 372     Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10   250.0
# 5      Amir Johnson      Boston Celtics    90.0       PF  29.0    6-9   240.0
# 68   Lucas Nogueira     Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN                 NaN     NaN      NaN   NaN    NaN     NaN
#
#        College      Salary
# 372     Kansas   3300000.0
# 5          NaN  12000000.0
# 68         NaN   1842000.0
# 1    Marquette   6796117.0
# 457        NaN         NaN

# %%
nba.sort_index(ascending=False , inplace = True)

# %%
nba.head(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0

# %% [markdown]
# ### Rank Value with the .rank() Method

# %%
nba = pd.read_csv("nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending  =False).astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by="Salary" , ascending = False).head(3)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
#
#      Weight   College    Salary  Salary Rank
# 109   212.0       NaN  25000000            1
# 169   250.0       NaN  22970500            2
# 33    240.0  Syracuse  22875000            3
